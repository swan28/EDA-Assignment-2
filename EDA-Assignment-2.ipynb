# %% [markdown]
# # 1. Amazon Sales Data
#
# ## Description
# This dataset contains information on **1K+** Amazon products, including their ratings, reviews, and other details.
#
# ## Features
#
# - **product_id**: Unique identifier for each product
# - **product_name**: Name of the product
# - **category**: Category of the product
# - **discounted_price**: Discounted price of the product
# - **actual_price**: Actual price of the product
# - **discount_percentage**: Percentage of discount for the product
# - **rating**: Rating of the product (1-5)
# - **rating_count**: Number of people who voted for the Amazon rating
# - **about_product**: Description of the product
# - **user_id**: ID of the user who wrote the review
# - **user_name**: Name of the user who wrote the review
# - **review_id**: Unique identifier for the review
# - **review_title**: Short review title
# - **review_content**: Full content of the review
# - **img_link**: Image link of the product
# - **product_link**: Official website link for the product
#
# ## Source
# [Amazon Sales Data](https://drive.google.com/file/d/1yKlW0x5yyRQijmWbEg5YCsq4wqLl3_oB/view)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("./amazon.csv")
df1
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3     Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4     Computers&Accessories|Accessories&Peripherals|...             ₹154
# ...                                                 ...              ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# 0          ₹1,099                 64%    4.2       24,269
# 1            ₹349                 43%    4.0       43,994
# 2          ₹1,899                 90%    3.9        7,928
# 3            ₹699                 53%    4.2       94,363
# 4            ₹399                 61%    4.2       16,905
# ...           ...                 ...    ...          ...
# 1460         ₹919                 59%      4        1,090
# 1461       ₹3,045                 25%    4.1        4,118
# 1462       ₹3,080                 28%    3.6          468
# 1463       ₹1,890                 26%      4        8,031
# 1464       ₹3,690                 22%    4.3        6,987
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 1     Compatible with all Type C enabled devices, be...
# 2     【 Fast Charger& Data Sync】-With built-in safet...
# 3     The boAt Deuce USB 300 2 in 1 cable is compati...
# 4     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                                                 ...
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                       230 Volts, 400 watts, 1 Year
# 1462  International design and styling|Two heat sett...
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                 ...
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2     Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3     Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4     rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                 ...
# 1460  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1461  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1462  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1463  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 0     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2     R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3     R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4     R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                 ...
# 1460  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1461  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1462  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1463  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     A Good Braided Cable for Your Type C Device,Go...
# 2     Good speed for earlier versions,Good Product,W...
# 3     Good product,Good one,Nice,Really nice product...
# 4     As good as original,Decent,Good one for second...
# ...                                                 ...
# 1460  Received the product without spanner,Excellent...
# 1461  ok,everything was good couldn't return bcoz I ...
# 1462  very good,Work but front melt after 2 month,Go...
# 1463  Fan Speed is slow,Good quality,Good product,go...
# 1464  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 0     Looks durable Charging is fine tooNo complains...
# 1     I ordered this cable to connect my phone to An...
# 2     Not quite durable and sturdy,https://m.media-a...
# 3     Good product,long wire,Charges good,Nice,I bou...
# 4     Bought this instead of original apple, does th...
# ...                                                 ...
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 1     https://m.media-amazon.com/images/W/WEBP_40237...
# 2     https://m.media-amazon.com/images/W/WEBP_40237...
# 3     https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4     https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                 ...
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2     https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3     https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4     https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                 ...
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1465 rows x 16 columns]

# %% [markdown]
# ### 1. What is the average rating for each product category?

# %%
df1.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df1['rating']
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460      4
# 1461    4.1
# 1462    3.6
# 1463      4
# 1464    4.3
# Name: rating, Length: 1465, dtype: object

# %%
df1['rating'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1465 entries, 0 to 1464
# Series name: rating
# Non-Null Count  Dtype
# --------------  -----
# 1465 non-null   object
# dtypes: object(1)
# memory usage: 11.6+ KB

# %%
df1.rating.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: rating, Length: 1465, dtype: bool

# %%
df1.rating.isnull().sum()
# Out:
# np.int64(0)

# %%
df1["rating"] = df1["rating"].replace('|', float('nan')).astype("float64")
df1.rating
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# Name: rating, Length: 1465, dtype: float64

# %%
# Average rating for each product category

average_rating=df1.groupby('category')['rating'].mean()
average_rating.round(2)
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    3.80
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   4.15
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           3.50
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        3.60
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           4.05
#                                                                                                                           ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        4.25
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|LiquidInkRollerballPens     4.15
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|RetractableBallpointPens    4.30
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|StickBallpointPens          4.13
# Toys&Games|Arts&Crafts|Drawing&PaintingSupplies|ColouringPens&Markers                                                     4.30
# Name: rating, Length: 211, dtype: float64

# %%
# Overall rating
print("Overall average rating:",average_rating.mean())
# Out:
# Overall average rating: 4.129893157821581

# %%
df1.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %% [markdown]
# ### 2. What are the top rating_count products by category?

# %%
df1.rating_count
# Out:
# 0       24,269
# 1       43,994
# 2        7,928
# 3       94,363
# 4       16,905
#          ...
# 1460     1,090
# 1461     4,118
# 1462       468
# 1463     8,031
# 1464     6,987
# Name: rating_count, Length: 1465, dtype: object

# %%
df1.rating_count.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: rating_count, Length: 1465, dtype: bool

# %%
df1.rating_count.isnull().sum()
# Out:
# np.int64(2)

# %%
df1.rating_count.fillna(0, inplace=True)

# %%
df1.rating_count.isnull().sum()
# Out:
# np.int64(0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1464 non-null   float64
#  7   rating_count         1465 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: float64(1), object(15)
# memory usage: 183.3+ KB

# %%
df1.rating_count.replace(",", "", regex=True, inplace=True)
df1["rating_count"] = df1['rating_count'].astype("int64")
df1.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price        object
# actual_price            object
# discount_percentage     object
# rating                 float64
# rating_count             int64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %%
temp_df1 = df1[df1['rating_count'].notnull()]
temp_df1
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3     Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4     Computers&Accessories|Accessories&Peripherals|...             ₹154
# ...                                                 ...              ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage  rating  rating_count  \
# 0          ₹1,099                 64%     4.2         24269
# 1            ₹349                 43%     4.0         43994
# 2          ₹1,899                 90%     3.9          7928
# 3            ₹699                 53%     4.2         94363
# 4            ₹399                 61%     4.2         16905
# ...           ...                 ...     ...           ...
# 1460         ₹919                 59%     4.0          1090
# 1461       ₹3,045                 25%     4.1          4118
# 1462       ₹3,080                 28%     3.6           468
# 1463       ₹1,890                 26%     4.0          8031
# 1464       ₹3,690                 22%     4.3          6987
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 1     Compatible with all Type C enabled devices, be...
# 2     【 Fast Charger& Data Sync】-With built-in safet...
# 3     The boAt Deuce USB 300 2 in 1 cable is compati...
# 4     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                                                 ...
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                       230 Volts, 400 watts, 1 Year
# 1462  International design and styling|Two heat sett...
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                 ...
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2     Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3     Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4     rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                 ...
# 1460  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1461  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1462  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1463  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 0     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2     R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3     R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4     R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                 ...
# 1460  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1461  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1462  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1463  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     A Good Braided Cable for Your Type C Device,Go...
# 2     Good speed for earlier versions,Good Product,W...
# 3     Good product,Good one,Nice,Really nice product...
# 4     As good as original,Decent,Good one for second...
# ...                                                 ...
# 1460  Received the product without spanner,Excellent...
# 1461  ok,everything was good couldn't return bcoz I ...
# 1462  very good,Work but front melt after 2 month,Go...
# 1463  Fan Speed is slow,Good quality,Good product,go...
# 1464  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 0     Looks durable Charging is fine tooNo complains...
# 1     I ordered this cable to connect my phone to An...
# 2     Not quite durable and sturdy,https://m.media-a...
# 3     Good product,long wire,Charges good,Nice,I bou...
# 4     Bought this instead of original apple, does th...
# ...                                                 ...
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 1     https://m.media-amazon.com/images/W/WEBP_40237...
# 2     https://m.media-amazon.com/images/W/WEBP_40237...
# 3     https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4     https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                 ...
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2     https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3     https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4     https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                 ...
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1465 rows x 16 columns]

# %%
# Top 10 rating_count products by rating_count

temp_df1[['category', 'product_name', 'rating_count']].nlargest(10, 'rating_count')
# Out:
#                                               category  \
# 12   Electronics|HomeTheater,TV&Video|Accessories|C...
# 47   Electronics|HomeTheater,TV&Video|Accessories|C...
# 65   Electronics|HomeTheater,TV&Video|Accessories|C...
# 684  Electronics|HomeTheater,TV&Video|Accessories|C...
# 352  Electronics|Headphones,Earbuds&Accessories|Hea...
# 400  Electronics|Headphones,Earbuds&Accessories|Hea...
# 584  Electronics|Headphones,Earbuds&Accessories|Hea...
# 370  Electronics|Mobiles&Accessories|Smartphones&Ba...
# 371  Electronics|Mobiles&Accessories|Smartphones&Ba...
# 473  Electronics|Mobiles&Accessories|Smartphones&Ba...
#
#                                           product_name  rating_count
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...        426973
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...        426973
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...        426973
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...        426972
# 352  boAt Bassheads 100 in Ear Wired Earphones with...        363713
# 400  boAt Bassheads 100 in Ear Wired Earphones with...        363713
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...        363711
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...        313836
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...        313836
# 473  Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB St...        313832

# %%
temp_df1[['category', 'product_name', 'rating_count']].sort_values(by='rating_count', ascending=False)
# Out:
#                                                category  \
# 12    Electronics|HomeTheater,TV&Video|Accessories|C...
# 65    Electronics|HomeTheater,TV&Video|Accessories|C...
# 47    Electronics|HomeTheater,TV&Video|Accessories|C...
# 684   Electronics|HomeTheater,TV&Video|Accessories|C...
# 400   Electronics|Headphones,Earbuds&Accessories|Hea...
# ...                                                 ...
# 1344  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# 1459  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
# 1309  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# 324   Computers&Accessories|Accessories&Peripherals|...
# 282   Computers&Accessories|Accessories&Peripherals|...
#
#                                            product_name  rating_count
# 12    AmazonBasics Flexible Premium HDMI Cable (Blac...        426973
# 65    Amazon Basics High-Speed HDMI Cable, 6 Feet (2...        426973
# 47    Amazon Basics High-Speed HDMI Cable, 6 Feet - ...        426973
# 684   AmazonBasics Flexible Premium HDMI Cable (Blac...        426972
# 400   boAt Bassheads 100 in Ear Wired Earphones with...        363713
# ...                                                 ...           ...
# 1344  Longway Blaze 2 Rod Quartz Room Heater (White,...             4
# 1459  NGI Store 2 Pieces Pet Hair Removers for Your ...             2
# 1309  Khaitan ORFin Fan heater for Home and kitchen-...             2
# 324   REDTECH USB-C to Lightning Cable 3.3FT, [Apple...             0
# 282   Amazon Brand - Solimo 65W Fast Charging Braide...             0
#
# [1465 rows x 3 columns]

# %%
# Top 10 rating_count products by category

top_10_products = temp_df1.groupby('category').apply(lambda x: x.nlargest(10, 'rating_count')).reset_index(drop=True)
top_10_products
# Out:
#      product_id                                       product_name  \
# 0    B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
# 1    B097C564GC  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 2    B094DQWV9B  Kanget [2 Pack] Type C Female to USB A Male Ch...
# 3    B009LJ2BXA  Hp Wired On Ear Headphones With Mic With 3.5 M...
# 4    B08SCCG9D4  JBL Commercial CSLM20B Auxiliary Omnidirection...
# ..          ...                                                ...
# 815  B00LOD70SC  Pilot V7 Liquid Ink Roller Ball Pen (2 Blue + ...
# 816  B07SBGFDX9     Pentonic Multicolor Ball Point Pen, Pack of 10
# 817  B00LZPQVMK  Parker Vector Standard Chrome Trim Ball Pen (I...
# 818  B0746N6WML  Parker Vector Camouflage Gift Set - Roller Bal...
# 819  B00DJ5N9VK  Faber-Castell Connector Pen Set - Pack of 25 (...
#
#                                               category discounted_price  \
# 0    Car&Motorbike|CarAccessories|InteriorAccessori...           ₹2,339
# 1    Computers&Accessories|Accessories&Peripherals|...             ₹294
# 2    Computers&Accessories|Accessories&Peripherals|...             ₹149
# 3    Computers&Accessories|Accessories&Peripherals|...             ₹649
# 4    Computers&Accessories|Accessories&Peripherals|...             ₹949
# ..                                                 ...              ...
# 815  OfficeProducts|OfficePaperProducts|Paper|Stati...             ₹178
# 816  OfficeProducts|OfficePaperProducts|Paper|Stati...             ₹120
# 817  OfficeProducts|OfficePaperProducts|Paper|Stati...             ₹272
# 818  OfficeProducts|OfficePaperProducts|Paper|Stati...             ₹341
# 819  Toys&Games|Arts&Crafts|Drawing&PaintingSupplie...             ₹150
#
#     actual_price discount_percentage  rating  rating_count  \
# 0         ₹4,000                 42%     3.8          1118
# 1         ₹4,999                 94%     4.3          4426
# 2           ₹399                 63%     4.0          1540
# 3           ₹999                 35%     3.5          7222
# 4         ₹2,000                 53%     3.9         14969
# ..           ...                 ...     ...           ...
# 815         ₹210                 15%     4.3          2450
# 816         ₹120                  0%     4.1          4308
# 817         ₹320                 15%     4.0          3686
# 818         ₹450                 24%     4.3          2493
# 819         ₹150                  0%     4.3         15867
#
#                                          about_product  \
# 0    [NEW LAUNCH - INNOVATIVE DESIGN] EFFICIENT PUR...
# 1    【WIDER COMPATIBILITY】This USB C Female to USB ...
# 2    👍【USB C TO USB ADAPTER】-This is a USB C FEMALE...
# 3    Powerful bass and clear treble sounds|Wired co...
# 4    Omnidirectional pickup pattern|3.5mm TRRS jack...
# ..                                                 ...
# 815  Unique 3 dimple tip technology from Japan for ...
# 816  0.7 mm tip size|Black Body, Multicolor Ink(Bla...
# 817  A solid plastic body of the glossy black desig...
# 818  This charming looking pen is made up of ABS pl...
# 819  Simply draw and color or clip these pens toget...
#
#                                                user_id  \
# 0    AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
# 1    AGO5SRT3ESLNL5WTRQFD5BSIYPQA,AGGNODUMRADB3PQQT...
# 2    AFA6YM4NTFRGHHKYN5U7HUYEVSUA,AEB3EVUTQCHIE3PGI...
# 3    AFIZUD4UBB67LGWY6CVLRHKA75IA,AG2TD3527KNZZNE46...
# 4    AFROXVCIF6PZXFXLS7DLTPT2CGCQ,AHA4ODJMDNBNUVEUS...
# ..                                                 ...
# 815  AG3G7G2DUJKN5YMCOYZNCADKKJUQ,AH44B2X6AT45J37MH...
# 816  AGK76H5VGHDWFQD7JTHVKZNQ5BHA,AHWXK2FU23OBRZZUA...
# 817  AE3S2ZAEMH765KUJ57DR6HBZBB3Q,AHSIVUNTJMI5S5AJG...
# 818  AFVTO4K2IG5AYWZPOAEA2QGPZZ4A,AHWTCTHLUKPJP2IUI...
# 819  AE5D3EMPETKIA4VU4SZU5UIHXKQA,AFF76KWKCMR6GNPUX...
#
#                                              user_name  \
# 0    Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
# 1    Naga Sai Gadagottu,Neha Sharma,Amazon Customer...
# 2    Abhi_K,Amazon Customer,Swap,shivam,Abhinav Sin...
# 3    Deepthi,Nitin Mishra,Raju Chacko,A.VISWANATHAR...
# 4    Ansh KaTariA,Saqlain Shaikh,Sardar V.,Rushikes...
# ..                                                 ...
# 815  Madhusmita singh,Sandeep Singh,Jay OG,Asim,Vik...
# 816  Parul S.,Prateek Tiwari,kateriki,golla ramesh,...
# 817  Fardeen mujawar,Pavan,Danny,Siddhartha Pratap,...
# 818  Good,Aayush,Nupur Gupta,Gunjan Sengupta,Syed T...
# 819  Aradhna Aadhya,sonali ghosh,Sam,VGRK,Surfer007...
#
#                                              review_id  \
# 0    R3TOOFPX256D59,R1PR50BDQOEIIO,R392FI4QWXWOX5,R...
# 1    R3CUNCZTU43JPP,RSO46BN8S4OSU,R2UD5D7T4DZRE5,R2...
# 2    R1QIWMR6C3F3U0,R1MSGOZTOMZE4B,R20OZCEE82GU0W,R...
# 3    R392ZYXC6D3GY0,R1MJHZXZ09ETAE,R20PJKJTCF9RXN,R...
# 4    R20M6JOASW88SS,RPM4RV2MQNNN0,R19KRP5SDTN2NL,R1...
# ..                                                 ...
# 815  R1AY8EXPHPWDDR,R24503W0UJGTMU,R27P97SD5T4MUX,R...
# 816  R1FXYA8WISUWTK,R2C5SUFAIFCKV9,RD87PA0KNH3GQ,R1...
# 817  RD6OIJUG0R241,R3EUJ7A6LG8X7V,R1DWGT4USEVGYK,R1...
# 818  R37OWPWWYU7L3G,R2AQ3J8DYODY55,RA0RPO7G5XXOL,R1...
# 819  R39PYNXMLNEIYW,R3AMNR0LJWNAUU,R2P5M80U8OL9OQ,R...
#
#                                           review_title  \
# 0    Liked it,User friendly and effective,Not as pe...
# 1    Tiny helping hand,Good product,As a whole good...
# 2    Good and does it’s work,Nice product working a...
# 3    Headset,Overall a good product. Sound quality ...
# 4    It's just good !,Good for WFH,Works according ...
# ..                                                 ...
# 815  It's good,Good,One of the few items on amazon ...
# 816  Average,I like the 'Pentonic' pens,which is wh...
# 817  Ok,Like all other ball pens,Regular pen over p...
# 818  Good,Made for special ones,Good Product,Awesom...
# 819  As this was my 2nd order for same product.2nd ...
#
#                                         review_content  \
# 0    As of now its working fine, but don't expect m...
# 1    This eliminates the need to buy chargers for t...
# 2    Using it to connect my type C Plantronic headp...
# 3    Not a perfect fit for long usage,One problem y...
# 4    It just good for beginners you can start your ...
# ..                                                 ...
# 815  Everything is fine but it's bit dark and stick...
# 816  It's good, but they give 2 different shades of...
# 817  Can buy but only when price is less,It's not t...
# 818  Good,Amazing,Nice pen and keychain,I just live...
# 819  Torn packing.dekhne me product used lg rha tha...
#
#                                               img_link  \
# 0    https://m.media-amazon.com/images/W/WEBP_40237...
# 1    https://m.media-amazon.com/images/W/WEBP_40237...
# 2    https://m.media-amazon.com/images/W/WEBP_40237...
# 3    https://m.media-amazon.com/images/I/31eE6slx4E...
# 4    https://m.media-amazon.com/images/I/41U9-x0JGP...
# ..                                                 ...
# 815  https://m.media-amazon.com/images/I/31pJvN8OkS...
# 816  https://m.media-amazon.com/images/I/410DCX0vt4...
# 817  https://m.media-amazon.com/images/W/WEBP_40237...
# 818  https://m.media-amazon.com/images/W/WEBP_40237...
# 819  https://m.media-amazon.com/images/I/41rJGx-w9i...
#
#                                           product_link
# 0    https://www.amazon.in/Reffair-AX30-MAX-Interna...
# 1    https://www.amazon.in/rts-Adapter-Charging-Con...
# 2    https://www.amazon.in/Kanget-Female-Adapter-St...
# 3    https://www.amazon.in/HP-B4B09PA-Headphones-wi...
# 4    https://www.amazon.in/JBL-Commercial-Omnidirec...
# ..                                                 ...
# 815  https://www.amazon.in/Pilot-Liquid-Roller-Ball...
# 816  https://www.amazon.in/Linc-Ball-Point-Pentonic...
# 817  https://www.amazon.in/Parker-Vector-Standard-B...
# 818  https://www.amazon.in/Parker-Vector-Camouflage...
# 819  https://www.amazon.in/Faber-Castell-Connector-...
#
# [820 rows x 16 columns]

# %%
top_10_products = top_10_products[['category', 'product_name', 'rating_count']]
top_10_products
# Out:
#                                               category  \
# 0    Car&Motorbike|CarAccessories|InteriorAccessori...
# 1    Computers&Accessories|Accessories&Peripherals|...
# 2    Computers&Accessories|Accessories&Peripherals|...
# 3    Computers&Accessories|Accessories&Peripherals|...
# 4    Computers&Accessories|Accessories&Peripherals|...
# ..                                                 ...
# 815  OfficeProducts|OfficePaperProducts|Paper|Stati...
# 816  OfficeProducts|OfficePaperProducts|Paper|Stati...
# 817  OfficeProducts|OfficePaperProducts|Paper|Stati...
# 818  OfficeProducts|OfficePaperProducts|Paper|Stati...
# 819  Toys&Games|Arts&Crafts|Drawing&PaintingSupplie...
#
#                                           product_name  rating_count
# 0    Reffair AX30 [MAX] Portable Air Purifier for C...          1118
# 1    rts [2 Pack] Mini USB C Type C Adapter Plug, T...          4426
# 2    Kanget [2 Pack] Type C Female to USB A Male Ch...          1540
# 3    Hp Wired On Ear Headphones With Mic With 3.5 M...          7222
# 4    JBL Commercial CSLM20B Auxiliary Omnidirection...         14969
# ..                                                 ...           ...
# 815  Pilot V7 Liquid Ink Roller Ball Pen (2 Blue + ...          2450
# 816     Pentonic Multicolor Ball Point Pen, Pack of 10          4308
# 817  Parker Vector Standard Chrome Trim Ball Pen (I...          3686
# 818  Parker Vector Camouflage Gift Set - Roller Bal...          2493
# 819  Faber-Castell Connector Pen Set - Pack of 25 (...         15867
#
# [820 rows x 3 columns]

# %%
top_10_products.sort_values(by='rating_count', ascending=False)[0:10]
# Out:
#                                               category  \
# 287  Electronics|HomeTheater,TV&Video|Accessories|C...
# 289  Electronics|HomeTheater,TV&Video|Accessories|C...
# 288  Electronics|HomeTheater,TV&Video|Accessories|C...
# 290  Electronics|HomeTheater,TV&Video|Accessories|C...
# 249  Electronics|Headphones,Earbuds&Accessories|Hea...
# 250  Electronics|Headphones,Earbuds&Accessories|Hea...
# 251  Electronics|Headphones,Earbuds&Accessories|Hea...
# 426  Electronics|Mobiles&Accessories|Smartphones&Ba...
# 427  Electronics|Mobiles&Accessories|Smartphones&Ba...
# 428  Electronics|Mobiles&Accessories|Smartphones&Ba...
#
#                                           product_name  rating_count
# 287  AmazonBasics Flexible Premium HDMI Cable (Blac...        426973
# 289  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...        426973
# 288  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...        426973
# 290  AmazonBasics Flexible Premium HDMI Cable (Blac...        426972
# 249  boAt Bassheads 100 in Ear Wired Earphones with...        363713
# 250  boAt Bassheads 100 in Ear Wired Earphones with...        363713
# 251  boAt BassHeads 100 in-Ear Wired Headphones wit...        363711
# 426  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...        313836
# 427  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...        313836
# 428  Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB St...        313832

# %% [markdown]
# ### 3. What is the distribution of discounted prices vs. actual prices?

# %%
df1.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df1[['discounted_price', 'actual_price']]
# Out:
#      discounted_price actual_price
# 0                ₹399       ₹1,099
# 1                ₹199         ₹349
# 2                ₹199       ₹1,899
# 3                ₹329         ₹699
# 4                ₹154         ₹399
# ...               ...          ...
# 1460             ₹379         ₹919
# 1461           ₹2,280       ₹3,045
# 1462           ₹2,219       ₹3,080
# 1463           ₹1,399       ₹1,890
# 1464           ₹2,863       ₹3,690
#
# [1465 rows x 2 columns]

# %%
df1.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price        object
# actual_price            object
# discount_percentage     object
# rating                 float64
# rating_count             int64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %%
# Convert discount and actual price in float
new_discounted_price=df1['discounted_price'].str.replace("₹", "").str.replace(",", "").astype("float")
new_discounted_price
# Out:
# 0        399.0
# 1        199.0
# 2        199.0
# 3        329.0
# 4        154.0
#          ...
# 1460     379.0
# 1461    2280.0
# 1462    2219.0
# 1463    1399.0
# 1464    2863.0
# Name: discounted_price, Length: 1465, dtype: float64

# %%
new_actual_price=df1['actual_price'].str.replace("₹", "").str.replace(",", "").astype("float")
new_actual_price
# Out:
# 0       1099.0
# 1        349.0
# 2       1899.0
# 3        699.0
# 4        399.0
#          ...
# 1460     919.0
# 1461    3045.0
# 1462    3080.0
# 1463    1890.0
# 1464    3690.0
# Name: actual_price, Length: 1465, dtype: float64

# %%
# plot discounted and actual price distribution

sns.scatterplot(x=new_discounted_price, y=new_actual_price)
plt.title('Distribution of discounted price vs. actual price')
plt.show()

# %% [markdown]
# ### **Insight**:
# As we can clearly see through the Scatterplot, as the actual price increases,Discounted price increases simultaneously. More precisely actual price and discounted price are linearly related.
#
# - --

# %% [markdown]
# ### 4. How does the average discount percentage vary across categories?

# %%
df1.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df1.discount_percentage
# Out:
# 0       64%
# 1       43%
# 2       90%
# 3       53%
# 4       61%
#        ...
# 1460    59%
# 1461    25%
# 1462    28%
# 1463    26%
# 1464    22%
# Name: discount_percentage, Length: 1465, dtype: object

# %%
# Replace % with blan and convert the datatype

df1['discount_percentage']=df1['discount_percentage'].str.replace('%', '').astype(float)
df1.discount_percentage
# Out:
# 0       64.0
# 1       43.0
# 2       90.0
# 3       53.0
# 4       61.0
#         ...
# 1460    59.0
# 1461    25.0
# 1462    28.0
# 1463    26.0
# 1464    22.0
# Name: discount_percentage, Length: 1465, dtype: float64

# %%
# Group by category

average_discount_by_category=df1.groupby('category')['discount_percentage'].mean()
average_discount_by_category
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    42.0
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   78.5
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           35.0
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        56.5
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           46.5
#                                                                                                                           ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens         0.0
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|LiquidInkRollerballPens      5.0
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|RetractableBallpointPens    17.5
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|StickBallpointPens          13.0
# Toys&Games|Arts&Crafts|Drawing&PaintingSupplies|ColouringPens&Markers                                                      0.0
# Name: discount_percentage, Length: 211, dtype: float64

# %%
average_discount_by_category.sort_values(ascending=False)
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors                            90.0
# Electronics|Headphones,Earbuds&Accessories|Earpads                                                                    90.0
# Electronics|Mobiles&Accessories|MobileAccessories|Décor|PhoneCharms                                                   90.0
# Electronics|Headphones,Earbuds&Accessories|Adapters                                                                   88.0
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MiceAccessories|DustCovers         87.5
#                                                                                                                       ...
# OfficeProducts|OfficeElectronics|Calculators|Financial&Business                                                        0.0
# OfficeProducts|OfficePaperProducts|Paper|Copy&PrintingPaper|ColouredPaper                                              0.0
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|FountainPens             0.0
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens     0.0
# Toys&Games|Arts&Crafts|Drawing&PaintingSupplies|ColouringPens&Markers                                                  0.0
# Name: discount_percentage, Length: 211, dtype: float64

# %%
df1.discount_percentage.mean()
# Out:
# np.float64(47.69146757679181)

# %%
more_than_average = (average_discount_by_category >= average_discount_by_category.mean()).sum()
less_than_average= (average_discount_by_category < average_discount_by_category.mean()).sum()
print("more_than_average:",more_than_average)
print("less_than_average:",less_than_average)
# Out:
# more_than_average: 115
# less_than_average: 96

# %% [markdown]
# ### **Insight**:
# Hence as per the study, there are 115 out of 211 categories which are having "average discount percentage" greater than or equal to overall mean viz: 47.69, while on the other hand, there are 96 categories out of 211, which are having less "average discount percentage" than 47.69 (overall mean).
#
# - --
#
# ### 5. What are the most popular product names?

# %%
df1.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
new_temp_df1=df1[["product_name","rating","rating_count"]]
new_temp_df1
# Out:
#                                            product_name  rating  rating_count
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...     4.2         24269
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...     4.0         43994
# 2     Sounce Fast Phone Charging Cable & Data Sync U...     3.9          7928
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...     4.2         94363
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...     4.2         16905
# ...                                                 ...     ...           ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...     4.0          1090
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...     4.1          4118
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...     3.6           468
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...     4.0          8031
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...     4.3          6987
#
# [1465 rows x 3 columns]

# %%
new_temp_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  1465 non-null   object
#  1   rating        1464 non-null   float64
#  2   rating_count  1465 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 34.5+ KB

# %%
#As the most popular product also have highest rating count
most_popular_products=new_temp_df1.sort_values(by="rating_count",ascending=False)

# find top 20 popular product
most_popular_products.head(20)
# Out:
#                                            product_name  rating  rating_count
# 12    AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4        426973
# 65    Amazon Basics High-Speed HDMI Cable, 6 Feet (2...     4.4        426973
# 47    Amazon Basics High-Speed HDMI Cable, 6 Feet - ...     4.4        426973
# 684   AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4        426972
# 400   boAt Bassheads 100 in Ear Wired Earphones with...     4.1        363713
# 352   boAt Bassheads 100 in Ear Wired Earphones with...     4.1        363713
# 584   boAt BassHeads 100 in-Ear Wired Headphones wit...     4.1        363711
# 371   Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...     4.1        313836
# 370   Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...     4.1        313836
# 566   Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...     4.1        313832
# 473   Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB St...     4.1        313832
# 760   boAt Bassheads 225 in Ear Wired Earphones with...     4.1        273189
# 1028  Pigeon Polypropylene Mini Handy and Compact Ch...     4.1        270563
# 588           SanDisk Cruzer Blade 32GB USB Flash Drive     4.3        253105
# 864   SanDisk Extreme SD UHS I 64GB Card for 4K Vide...     4.5        205052
# 347   JBL C100SI Wired In Ear Headphones with Mic, J...     4.1        192590
# 479   JBL C100SI Wired In Ear Headphones with Mic, J...     4.1        192589
# 598   JBL C100SI Wired In Ear Headphones with Mic, J...     4.1        192587
# 718   SanDisk Ultra Dual 64 GB USB 3.0 OTG Pen Drive...     4.3        189104
# 591   boAt Airdopes 121v2 in-Ear True Wireless Earbu...     3.8        180998

# %% [markdown]
# ### 6. What are the most popular product keywords?

# %%
# Assuming your DataFrame is named 'amazon_sales_data'

keywords = df1["product_name"].str.cat(df1["about_product"],sep=" ",na_rep="").str.lower().str.split()

#Flatten the list
word_list=[word for sublist in keywords for word in sublist]

#Count the frequency of words
word_count=pd.Series(word_list)
word_count.value_counts()

#Top 20 most popular product keywords used are:
top_keywords=word_count.value_counts().head(20)
print(top_keywords)
# Out:
# and      5590
# the      4342
# to       3995
# with     3837
# for      3226
# of       2200
# a        1905
# |        1888
# your     1880
# is       1481
# in       1372
# usb      1346
# &        1326
# you      1256
# cable    1026
# or        983
# on        980
# it        956
# -         900
# can       891
# Name: count, dtype: int64

# %% [markdown]
# ### 7. What are the most popular product reviews?

# %%
df1.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
popular_reviews = df1.sort_values(by='rating_count', ascending=False)[['product_name', 'about_product', 'rating_count',"review_title","review_content"]].head(5)

popular_reviews
# Out:
#                                           product_name  \
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 400  boAt Bassheads 100 in Ear Wired Earphones with...
#
#                                          about_product  rating_count  \
# 12   Flexible, lightweight HDMI cable for connectin...        426973
# 65   HDMI A Male to A Male Cable: Supports Ethernet...        426973
# 47   Please select appropriate display resolution &...        426973
# 684  Flexible, lightweight HDMI cable for connectin...        426972
# 400  The perfect way to add some style and stand ou...        363713
#
#                                           review_title  \
# 12   It's quite good and value for money,Works well...
# 65   It's quite good and value for money,Works well...
# 47   It's quite good and value for money,Works well...
# 684  It's quite good and value for money,Works well...
# 400  Best value for money,HEAD PHONE POUCH NOT RECE...
#
#                                         review_content
# 12   I am using it for 14 days now. The experience ...
# 65   I am using it for 14 days now. The experience ...
# 47   I am using it for 14 days now. The experience ...
# 684  I am using it for 14 days now. The experience ...
# 400  The sound quality of this earphone are really ...

# %% [markdown]
# ### 8. What is the correlation between discounted_price and rating?

# %%
df1.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#   actual_price  discount_percentage  rating  rating_count  \
# 0       ₹1,099                 64.0     4.2         24269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...

# %%
new_temp_df1=df1[['discounted_price', 'rating']]
new_temp_df1
# Out:
#      discounted_price  rating
# 0                ₹399     4.2
# 1                ₹199     4.0
# 2                ₹199     3.9
# 3                ₹329     4.2
# 4                ₹154     4.2
# ...               ...     ...
# 1460             ₹379     4.0
# 1461           ₹2,280     4.1
# 1462           ₹2,219     3.6
# 1463           ₹1,399     4.0
# 1464           ₹2,863     4.3
#
# [1465 rows x 2 columns]

# %%
# Replace ₹ and , and change the datatype

new_temp_df1["discounted_price"]=new_temp_df1["discounted_price"].str.replace("₹","").str.replace(",","").astype(float)

new_temp_df1
# Out:
#       discounted_price  rating
# 0                399.0     4.2
# 1                199.0     4.0
# 2                199.0     3.9
# 3                329.0     4.2
# 4                154.0     4.2
# ...                ...     ...
# 1460             379.0     4.0
# 1461            2280.0     4.1
# 1462            2219.0     3.6
# 1463            1399.0     4.0
# 1464            2863.0     4.3
#
# [1465 rows x 2 columns]

# %%
new_temp_df1.corr()
# Out:
#                   discounted_price    rating
# discounted_price          1.000000  0.120337
# rating                    0.120337  1.000000

# %%
sns.scatterplot(x=new_temp_df1["discounted_price"],y=new_temp_df1["rating"],color="r")
plt.title("Correlation between Rating and Discounted_price")
plt.show()

# %% [markdown]
# ### Insight and Conclusion:
# As per the above studies suggest that Rating and Discounted_price has very weak positive correlation of 0.12, which suggest that as the rating increases the increase in discounted_price also happens slightly, But a the correlation is not so strong we should keep other factors in mind too. There may be other factors such as product quality, brand reputation, or market demand that influence both the rating and the discounted price of a product. So, it's always a good idea to consider multiple factors before drawing any conclusions.
#
# - --
#
# ### 9. What are the Top 5 categories based on the highest ratings?

# %%
df1.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
temp_df1=df1[["category","rating","rating_count"]]
temp_df1
# Out:
#                                                category  rating  rating_count
# 0     Computers&Accessories|Accessories&Peripherals|...     4.2         24269
# 1     Computers&Accessories|Accessories&Peripherals|...     4.0         43994
# 2     Computers&Accessories|Accessories&Peripherals|...     3.9          7928
# 3     Computers&Accessories|Accessories&Peripherals|...     4.2         94363
# 4     Computers&Accessories|Accessories&Peripherals|...     4.2         16905
# ...                                                 ...     ...           ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...     4.0          1090
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...     4.1          4118
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...     3.6           468
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...     4.0          8031
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...     4.3          6987
#
# [1465 rows x 3 columns]

# %%
temp_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   category      1465 non-null   object
#  1   rating        1464 non-null   float64
#  2   rating_count  1465 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 34.5+ KB

# %%
# Top 5 categories based on rating

temp_df1.sort_values(by='rating', ascending=False).head(5)
# Out:
#                                                category  rating  rating_count
# 174   Computers&Accessories|Accessories&Peripherals|...     5.0             5
# 324   Computers&Accessories|Accessories&Peripherals|...     5.0             0
# 775   Computers&Accessories|Accessories&Peripherals|...     5.0            23
# 1299  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...     4.8          3964
# 1201  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...     4.8            28

# %%
# Top 5 categories based on rating_count

temp_df1.sort_values(by='rating_count', ascending=False).head(5)
# Out:
#                                               category  rating  rating_count
# 12   Electronics|HomeTheater,TV&Video|Accessories|C...     4.4        426973
# 65   Electronics|HomeTheater,TV&Video|Accessories|C...     4.4        426973
# 47   Electronics|HomeTheater,TV&Video|Accessories|C...     4.4        426973
# 684  Electronics|HomeTheater,TV&Video|Accessories|C...     4.4        426972
# 400  Electronics|Headphones,Earbuds&Accessories|Hea...     4.1        363713

# %% [markdown]
# ### 10. Identify any potential areas for improvement or optimization based on the data analysis.
#
# ans =>  Based on the data analysis, some potential areas for improvement or optimization could be as follows:
#
# 1. Improving the product's rating by addressing any issues mentioned in the reviews.
# 2. Increasing the number of rating counts to provide a more accurate representation of customer satisfaction.
# 3. Enhancing the product descriptions to better highlight its features and benefits.
# 4. Adjusting the pricing strategy to maximize the discount percentage and attract more customers.

# %% [markdown]
# - --
# - --
#
# # 2. Spotify Data: Popular Hip-hop Artists and Tracks
#
# ## Description
# The dataset titled **"Spotify Data: Popular Hip-hop Artists and Tracks"** provides a curated collection of approximately 500 entries showcasing the vibrant realm of hip-hop music. These entries meticulously compile the most celebrated hip-hop tracks and artists, reflecting their significant influence on the genre's landscape. Each entry highlights not only the popularity and musical composition of the tracks but also the creative prowess of the artists and their profound impact on global listeners.
#
# ## Application in Data Science
# This dataset serves as a valuable resource for various data science explorations:
# - **Trend Analysis**: Analyze the popularity dynamics of hit hip-hop tracks over recent years.
# - **Network Analysis**: Explore collaborative patterns among top artists and uncover insights into the genre's evolving collaborative landscape.
# - **Predictive Modeling**: Develop models to forecast track popularity based on diverse features, offering insights for artists, producers, and marketers.
#
# ## Features (Column Descriptors)
#
# - **Artist**: The name of the artist, providing direct attribution to the creative mind behind the track.
# - **Track Name**: The title of the track, encapsulating its identity and essence.
# - **Popularity**: A numeric score reflecting the track's reception and appeal among Spotify listeners.
# - **Duration (ms)**: The track's length in milliseconds, detailing the temporal extent of the musical experience.
# - **Track ID**: A unique identifier within Spotify's ecosystem, enabling direct access to the track for further exploration.
#
# ## Source
# [Spotify Data: Popular Hip-hop Artists and Tracks](https://drive.google.com/file/d/1JVgy2yXUOREkzRdCeWjep626uvvF94pP/view)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2=pd.read_csv("./spotify.csv")
df2
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# 1            91         173986  1zi7xx7UVEFkmKfv06H8x0
# 2            90         260111  2YSzYUF3jWqb9YP9VXmpjE
# 3            88         247444  7aqfrAY2p9BUSiupwk3svU
# 4            88         218364  3F5CgOj3wFlRv51JsHbxhe
# ..          ...            ...                     ...
# 435          44         221863  3fBsEOnzwtlkpS0LxXAZhN
# 436          64         191900  7Ezwtgfw7khBrpvaNPtMoT
# 437          69         283693  7xVLFuuYdAvcTfcP3IG3dS
# 438          65         220408  4hGmQboiou09EwhcTWa0H6
# 439          68         267720  0nq6sfr8z1R5KJ4XUk396e
#
# [440 rows x 5 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %% [markdown]
# ### 1. Load the dataframe and ensure data quality by checking for missing values and duplicate rows.
# Handle missing values and remove duplicate rows if necessary.

# %%
df2.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
df2.duplicated().sum()
# Out:
# np.int64(27)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.isna().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %% [markdown]
# ### 2. What is the distribution of popularity among the tracks in the dataset?
# Visualize it using a histogram.

# %%
df2.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df2['Popularity'], bins=20, kde=True)
plt.title('Distribution of Popularity')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3. Is there any relationship between the popularity and the duration of tracks?
# Explore this using a scatter plot.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Duration (ms)', y='Popularity', data=df2)
plt.title('Scatter Plot of Popularity vs. Duration')
plt.xlabel('Duration (ms)')
plt.ylabel('Popularity')
plt.show()

# %% [markdown]
# ### 4. Which artist has the highest number of tracks in the dataset?
# Display the count of tracks for each artist using a countplot.

# %%
plt.figure(figsize=(30, 8))
sns.countplot(x='Artist', data=df2, order=df2['Artist'].value_counts().index, palette='pastel')
plt.title('Countplot of Artists')
plt.xlabel('Artist')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### 5. What are the top 5 least popular tracks in the dataset?
# Provide the artist name and track name for each.

# %%
df2.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
df_sorted = df2.sort_values(by='Popularity')[['Track Name', 'Popularity']].head(5)
df_sorted
# Out:
#                         Track Name  Popularity
# 207  Attachments (feat. Coi Leray)          29
# 231                     Intentions          35
# 413                Splash Brothers          44
# 225                  On Me - Remix          47
# 407      911 (feat. Mary J. Blige)          48

# %% [markdown]
# ### 6. Among the top 5 most popular artists, which artist has the highest popularity on average?
# Calculate and display the average popularity for each artist.

# %%
avg = df2.groupby('Artist')['Popularity'].mean()
avg
# Out:
# Artist
# *NSYNC                    67.00
# 2 Chainz                  72.00
# 21 Savage                 83.80
# A Boogie Wit da Hoodie    80.00
# A$AP Ferg                 69.00
#                           ...
# Young Nudy                67.00
# Young Thug                73.75
# benny blanco              72.00
# cassö                     92.00
# ¥$                        85.10
# Name: Popularity, Length: 115, dtype: float64

# %%
df2.sort_values(by='Popularity', ascending=False)[['Artist', 'Popularity']].head(5)
# Out:
#            Artist  Popularity
# 40    Jack Harlow          97
# 260            ¥$          96
# 70      21 Savage          96
# 30   Travis Scott          93
# 0           Drake          92

# %% [markdown]
# ### 7. For the top 5 most popular artists, what are their most popular tracks?
# List the track name for each artist.

# %%
df_sorted = df2.sort_values(by='Popularity', ascending=False)
df_sorted
# Out:
#              Artist                               Track Name  Popularity  \
# 40      Jack Harlow                              Lovin On Me          97
# 260              ¥$                                 CARNIVAL          96
# 70        21 Savage                                   redrum          96
# 30     Travis Scott               FE!N (feat. Playboi Carti)          93
# 0             Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92
# ..              ...                                      ...         ...
# 407     Wyclef Jean                911 (feat. Mary J. Blige)          48
# 225        Lil Baby                            On Me - Remix          47
# 413  French Montana                          Splash Brothers          44
# 231   Justin Bieber                               Intentions          35
# 207          Pressa            Attachments (feat. Coi Leray)          29
#
#      Duration (ms)                Track ID
# 40          138411  4xhsWYTOGcal8zt0J161CU
# 260         264324  3w0w2T288dec0mgeZZqoNN
# 70          270697  52eIcoLUM25zbQupAZYoFh
# 30          191700  42VsgItocQwOQC3XWZ8JNA
# 0           319191  1yeB8MUNeLo9Ek1UEpsyz6
# ..             ...                     ...
# 407         259333  28hgx2bWXcaBJeC9zVwrBq
# 225         135444  2uUFVnVFERNxUdcmvEs7LB
# 413         221863  3fBsEOnzwtlkpS0LxXAZhN
# 231         212853  7jAVt70Xdg8EwOtsFB1ZqK
# 207         171000  6EfJ8Ct3GHbBz2YlyPnMYb
#
# [413 rows x 5 columns]

# %%
df_sorted[['Artist', 'Track Name']].head(5)
# Out:
#            Artist                               Track Name
# 40    Jack Harlow                              Lovin On Me
# 260            ¥$                                 CARNIVAL
# 70      21 Savage                                   redrum
# 30   Travis Scott               FE!N (feat. Playboi Carti)
# 0           Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)

# %% [markdown]
# ### 8. Visualize relationships between multiple numerical variables simultaneously using a pair plot.

# %%
sns.pairplot(df2)
plt.show()

# %%
df2
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 433  French Montana                                       Stand United
# 434    Jason Derulo                     Tip Toe (feat. French Montana)
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# 1            91         173986  1zi7xx7UVEFkmKfv06H8x0
# 2            90         260111  2YSzYUF3jWqb9YP9VXmpjE
# 3            88         247444  7aqfrAY2p9BUSiupwk3svU
# 4            88         218364  3F5CgOj3wFlRv51JsHbxhe
# ..          ...            ...                     ...
# 433          54         163971  01CHrTerCzyRpMI1MzQ4fz
# 434          65         187521  0TY3jVGwGDwDabLyQLVRQQ
# 436          64         191900  7Ezwtgfw7khBrpvaNPtMoT
# 437          69         283693  7xVLFuuYdAvcTfcP3IG3dS
# 438          65         220408  4hGmQboiou09EwhcTWa0H6
#
# [413 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Identify and label encode categorical columns
label_encoder = LabelEncoder()
for column in df2.select_dtypes(include='object').columns:
    df2[column] = label_encoder.fit_transform(df2[column])

# Calculate the correlation matrix
correlation_matrix = df2.corr()

# Plot the correlation matrix heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### 9. Does the duration of tracks vary significantly across different artists?
# Explore this visually using a box plot or violin plot.

# %%
sns.boxplot(df2,x="Popularity",y="Duration (ms)")
# Out:
# <Axes: xlabel='Popularity', ylabel='Duration (ms)'>
